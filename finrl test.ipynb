# %%
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to /private/var/folders/zc/zhbfk_hn05q0qbr8yp3_7t1w0000gn/T/pip-req-build-s7sk9ipz
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git /private/var/folders/zc/zhbfk_hn05q0qbr8yp3_7t1w0000gn/T/pip-req-build-s7sk9ipz
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit 53e32836ccb314604a61020253705c31770b1c78
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /private/var/folders/zc/zhbfk_hn05q0qbr8yp3_7t1w0000gn/T/pip-install-ems8ox13/elegantrl_e267086d49aa42cb9798795e9d2a9468
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git /private/var/folders/zc/zhbfk_hn05q0qbr8yp3_7t1w0000gn/T/pip-install-ems8ox13/elegantrl_e267086d49aa42cb9798795e9d2a9468
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 59fe4b4a1cca0a28e8a5fa4fb80eed9b5d472978
#   Preparing metadata (setup.py) ... done
# Collecting stable-baselines3[extra]>=2.0.0a5
#   Downloading stable_baselines3-2.0.0-py3-none-any.whl (178 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 178.4/178.4 kB 2.7 MB/s eta 0:00:003.2 MB/s eta 0:00:01
# Requirement already satisfied: scikit-learn<2,>=1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (1.0.2)
# Requirement already satisfied: alpaca-trade-api<4,>=3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (3.0.0)
# Collecting pyportfolioopt<2,>=1
#   Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.9/61.9 kB 5.6 MB/s eta 0:00:00
# Requirement already satisfied: ray[default,tune]<3,>=2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (2.3.1)
# Requirement already satisfied: wrds<4,>=3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (3.1.6)
# Requirement already satisfied: stockstats<0.6,>=0.5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (0.5.2)
# Requirement already satisfied: ccxt<4,>=3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (3.0.66)
# Collecting exchange-calendars<5,>=4
#   Downloading exchange_calendars-4.2.8-py3-none-any.whl (191 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 191.4/191.4 kB 3.2 MB/s eta 0:00:00 MB/s eta 0:00:01
# Requirement already satisfied: jqdatasdk<2,>=1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (1.8.11)
# Requirement already satisfied: yfinance<0.3,>=0.2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (0.2.17)
# Requirement already satisfied: pyfolio<0.10,>=0.9 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from finrl==0.3.6) (0.9.2+75.g4b901f6)
# Requirement already satisfied: requests<3,>2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.28.2)
# Requirement already satisfied: aiohttp==3.8.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (3.8.1)
# Requirement already satisfied: PyYAML==6.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: numpy>=1.11.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.22.4)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (0.58.0)
# Requirement already satisfied: msgpack==1.0.3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: websockets<11,>=9.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (10.4)
# Requirement already satisfied: pandas>=0.18.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: urllib3<2,>1.24 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from alpaca-trade-api<4,>=3->finrl==0.3.6) (1.26.15)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.3.3)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (4.0.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (2.0.4)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (6.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (22.1.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiohttp==3.8.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (1.8.2)
# Requirement already satisfied: packaging in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from deprecation==2.1.0->alpaca-trade-api<4,>=3->finrl==0.3.6) (23.0)
# Requirement already satisfied: setuptools>=60.9.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (65.6.3)
# Requirement already satisfied: aiodns>=1.1.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (3.0.0)
# Requirement already satisfied: certifi>=2018.1.18 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (2022.12.7)
# Requirement already satisfied: cryptography>=2.6.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ccxt<4,>=3->finrl==0.3.6) (39.0.1)
# Requirement already satisfied: pytz in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2022.7)
# Requirement already satisfied: pyluach in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: korean-lunar-calendar in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.3.1)
# Requirement already satisfied: toolz in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (0.12.0)
# Requirement already satisfied: python-dateutil in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from exchange-calendars<5,>=4->finrl==0.3.6) (2.8.2)
# Requirement already satisfied: pymysql>=0.7.6 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.0.3)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.4.39)
# Requirement already satisfied: thriftpy2>=0.3.9 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (0.4.16)
# Requirement already satisfied: six in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from jqdatasdk<2,>=1->finrl==0.3.6) (1.16.0)
# Requirement already satisfied: ipython>=3.2.3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (8.12.0)
# Requirement already satisfied: empyrical>=0.5.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: scipy>=0.14.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (1.7.3)
# Requirement already satisfied: seaborn>=0.7.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (0.12.2)
# Requirement already satisfied: matplotlib>=1.4.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pyfolio<0.10,>=0.9->finrl==0.3.6) (3.7.1)
# Collecting cvxpy<2.0.0,>=1.1.19
#   Downloading cvxpy-1.3.2-cp310-cp310-macosx_10_9_x86_64.whl (936 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 936.2/936.2 kB 2.8 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: virtualenv>=20.0.24 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (20.21.0)
# Requirement already satisfied: jsonschema in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (4.17.3)
# Requirement already satisfied: protobuf!=3.19.5,>=3.15.3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.20.3)
# Requirement already satisfied: grpcio<=1.49.1,>=1.42.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.49.1)
# Requirement already satisfied: filelock in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (3.9.0)
# Requirement already satisfied: click>=7.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (8.1.3)
# Requirement already satisfied: aiohttp-cors in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: gpustat>=1.0.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.1)
# Requirement already satisfied: py-spy>=0.2.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.14)
# Requirement already satisfied: opencensus in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.11.2)
# Requirement already satisfied: smart-open in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (5.2.1)
# Requirement already satisfied: colorful in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.5.5)
# Requirement already satisfied: pydantic in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (1.10.7)
# Requirement already satisfied: prometheus-client>=0.7.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.14.1)
# Requirement already satisfied: tensorboardX>=1.9 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (2.6)
# Requirement already satisfied: tabulate in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ray[default,tune]<3,>=2->finrl==0.3.6) (0.8.10)
# Requirement already satisfied: joblib>=0.11 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (1.1.1)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from scikit-learn<2,>=1->finrl==0.3.6) (2.2.0)
# Requirement already satisfied: torch>=1.11 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Collecting gymnasium==0.28.1
#   Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 4.3 MB/s eta 0:00:00m eta 0:00:010:01:01
# Requirement already satisfied: cloudpickle in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.0.0)
# Requirement already satisfied: pygame in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.0)
# Requirement already satisfied: rich in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (13.3.3)
# Requirement already satisfied: tqdm in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.65.0)
# Requirement already satisfied: tensorboard>=2.9.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.12.1)
# Requirement already satisfied: psutil in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.9.0)
# Collecting opencv-python
#   Downloading opencv_python-4.8.0.76-cp37-abi3-macosx_10_16_x86_64.whl (54.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.7/54.7 MB 7.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Collecting shimmy[atari]~=0.2.1
#   Downloading Shimmy-0.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: pillow in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (9.4.0)
# Collecting autorom[accept-rom-license]~=0.6.0
#   Downloading AutoROM-0.6.1-py3-none-any.whl (9.4 kB)
# Collecting farama-notifications>=0.0.1
#   Downloading Farama_Notifications-0.0.4-py3-none-any.whl (2.5 kB)
# Collecting jax-jumpy>=1.0.0
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: typing-extensions>=4.3.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from gymnasium==0.28.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.4.0)
# Requirement already satisfied: psycopg2-binary in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from wrds<4,>=3->finrl==0.3.6) (2.9.6)
# Requirement already satisfied: multitasking>=0.0.7 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (0.0.11)
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.12.0)
# Requirement already satisfied: html5lib>=1.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.1)
# Requirement already satisfied: lxml>=4.9.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (4.9.2)
# Requirement already satisfied: frozendict>=2.3.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (2.3.7)
# Requirement already satisfied: appdirs>=1.4.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from yfinance<0.3,>=0.2->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: gym in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (0.21.0)
# Requirement already satisfied: pycares>=4.0.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from aiodns>=1.1.1->ccxt<4,>=3->finrl==0.3.6) (4.3.0)
# Collecting AutoROM.accept-rom-license
#   Downloading AutoROM.accept-rom-license-0.6.1.tar.gz (434 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 434.7/434.7 kB 1.8 MB/s eta 0:00:002.4 MB/s eta 0:00:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: soupsieve>1.2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance<0.3,>=0.2->finrl==0.3.6) (2.4)
# Requirement already satisfied: cffi>=1.12 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (1.15.1)
# Collecting ecos>=2
#   Downloading ecos-2.0.12-cp310-cp310-macosx_10_9_x86_64.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.6/90.6 kB 4.5 MB/s eta 0:00:00
# Collecting scs>=1.1.6
#   Downloading scs-3.2.3-cp310-cp310-macosx_10_9_x86_64.whl (11.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.6/11.6 MB 4.5 MB/s eta 0:00:00m eta 0:00:01:01:01
# Collecting osqp>=0.4.1
#   Downloading osqp-0.6.3-cp310-cp310-macosx_10_9_x86_64.whl (252 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 252.6/252.6 kB 15.5 MB/s eta 0:00:00
# Requirement already satisfied: pandas-datareader>=0.2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from empyrical>=0.5.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.10.0)
# Requirement already satisfied: nvidia-ml-py>=11.450.129 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (11.525.112)
# Requirement already satisfied: blessed>=1.17.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (1.20.0)
# Requirement already satisfied: webencodings in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from html5lib>=1.1->yfinance<0.3,>=0.2->finrl==0.3.6) (0.5.1)
# Requirement already satisfied: decorator in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.36)
# Requirement already satisfied: matplotlib-inline in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.15.0)
# Requirement already satisfied: pexpect>4.3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.8.0)
# Requirement already satisfied: traitlets>=5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (5.7.1)
# Requirement already satisfied: pickleshare in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.5)
# Requirement already satisfied: appnope in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.1.2)
# Requirement already satisfied: stack-data in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: backcall in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.0)
# Requirement already satisfied: cycler>=0.10 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (4.25.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.0.5)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (1.4.4)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from matplotlib>=1.4.0->pyfolio<0.10,>=0.9->finrl==0.3.6) (3.0.9)
# Requirement already satisfied: tzdata>=2022.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pandas>=0.18.1->alpaca-trade-api<4,>=3->finrl==0.3.6) (2023.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from requests<3,>2->alpaca-trade-api<4,>=3->finrl==0.3.6) (3.4)
# Collecting ale-py~=0.8.1
#   Downloading ale_py-0.8.1-cp310-cp310-macosx_10_15_x86_64.whl (1.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 3.9 MB/s eta 0:00:00m eta 0:00:010:00:01
# Requirement already satisfied: greenlet!=0.4.17 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk<2,>=1->finrl==0.3.6) (2.0.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.17.2)
# Requirement already satisfied: absl-py>=0.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.4.0)
# Requirement already satisfied: google-auth-oauthlib<1.1,>=0.5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.0.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.3)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: wheel>=0.26 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.38.4)
# Requirement already satisfied: markdown>=2.6.8 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.4.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.8.1)
# Requirement already satisfied: ply<4.0,>=3.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from thriftpy2>=0.3.9->jqdatasdk<2,>=1->finrl==0.3.6) (3.11)
# Requirement already satisfied: networkx in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.8.4)
# Requirement already satisfied: jinja2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.1.2)
# Requirement already satisfied: sympy in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.11.1)
# Requirement already satisfied: platformdirs<4,>=2.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from virtualenv>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (2.5.2)
# Requirement already satisfied: distlib<1,>=0.3.6 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from virtualenv>=20.0.24->ray[default,tune]<3,>=2->finrl==0.3.6) (0.3.6)
# Requirement already satisfied: box2d-py==2.3.5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.3.5)
# Requirement already satisfied: pyglet>=1.4.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from gym->elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.6) (2.0.5)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from jsonschema->ray[default,tune]<3,>=2->finrl==0.3.6) (0.18.0)
# Requirement already satisfied: opencensus-context>=0.1.3 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (0.1.3)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (2.11.0)
# Requirement already satisfied: markdown-it-py<3.0.0,>=2.2.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.2.0)
# Collecting importlib-resources
#   Downloading importlib_resources-6.0.1-py3-none-any.whl (34 kB)
# Requirement already satisfied: wcwidth>=0.1.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from blessed>=1.17.1->gpustat>=1.0.0->ray[default,tune]<3,>=2->finrl==0.3.6) (0.2.5)
# Requirement already satisfied: pycparser in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt<4,>=3->finrl==0.3.6) (2.21)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default,tune]<3,>=2->finrl==0.3.6) (1.59.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (5.3.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (4.9)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.3.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mdurl~=0.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from markdown-it-py<3.0.0,>=2.2.0->rich->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.1.2)
# Collecting qdldl
#   Downloading qdldl-0.1.7.post0-cp310-cp310-macosx_10_9_x86_64.whl (105 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.2/105.2 kB 6.7 MB/s eta 0:00:00
# Requirement already satisfied: ptyprocess>=0.5 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.7.0)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (2.1.1)
# Requirement already satisfied: pure-eval in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.2.2)
# Requirement already satisfied: asttokens in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (2.0.5)
# Requirement already satisfied: executing in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from stack-data->ipython>=3.2.3->pyfolio<0.10,>=0.9->finrl==0.3.6) (0.8.3)
# Requirement already satisfied: mpmath>=0.19 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages/mpmath-1.2.1-py3.10.egg (from sympy->torch>=1.11->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (1.2.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<1.1,>=0.5->tensorboard>=2.9.1->stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6) (3.2.2)
# Building wheels for collected packages: finrl, AutoROM.accept-rom-license
#   Building wheel for finrl (pyproject.toml) ... done
#   Created wheel for finrl: filename=finrl-0.3.6-py3-none-any.whl size=4669336 sha256=46612b5ff10ece41750838a4e4194289b2a5480866d810530a9e65d3f8cf50ef
#   Stored in directory: /private/var/folders/zc/zhbfk_hn05q0qbr8yp3_7t1w0000gn/T/pip-ephem-wheel-cache-g0uwrqsw/wheels/72/3b/1a/0fc805a8cc65ecd5bfe4f74a3c586b6075678b8ba53fd8f749
#   Building wheel for AutoROM.accept-rom-license (pyproject.toml) ... done
#   Created wheel for AutoROM.accept-rom-license: filename=AutoROM.accept_rom_license-0.6.1-py3-none-any.whl size=446660 sha256=eb75f0ea4ed9747f158af5cdc0c5920a508437aee972d35a72f50327ec2b16e6
#   Stored in directory: /Users/lucasabbade/Library/Caches/pip/wheels/6b/1b/ef/a43ff1a2f1736d5711faa1ba4c1f61be1131b8899e6a057811
# Successfully built finrl AutoROM.accept-rom-license
# Installing collected packages: farama-notifications, opencv-python, jax-jumpy, importlib-resources, scs, qdldl, gymnasium, ecos, AutoROM.accept-rom-license, autorom, ale-py, stable-baselines3, shimmy, osqp, exchange-calendars, cvxpy, pyportfolioopt, finrl
#   Attempting uninstall: gymnasium
#     Found existing installation: Gymnasium 0.26.3
#     Uninstalling Gymnasium-0.26.3:
#       Successfully uninstalled Gymnasium-0.26.3
#   Attempting uninstall: stable-baselines3
#     Found existing installation: stable-baselines3 1.8.0
#     Uninstalling stable-baselines3-1.8.0:
#       Successfully uninstalled stable-baselines3-1.8.0
#   Attempting uninstall: exchange-calendars
#     Found existing installation: exchange-calendars 3.6.3
#     Uninstalling exchange-calendars-3.6.3:
#       Successfully uninstalled exchange-calendars-3.6.3
#   Attempting uninstall: finrl
#     Found existing installation: finrl 0.3.5
#     Uninstalling finrl-0.3.5:
#       Successfully uninstalled finrl-0.3.5
# Successfully installed AutoROM.accept-rom-license-0.6.1 ale-py-0.8.1 autorom-0.6.1 cvxpy-1.3.2 ecos-2.0.12 exchange-calendars-4.2.8 farama-notifications-0.0.4 finrl-0.3.6 gymnasium-0.28.1 importlib-resources-6.0.1 jax-jumpy-1.0.0 opencv-python-4.8.0.76 osqp-0.6.3 pyportfolioopt-1.5.5 qdldl-0.1.7.post0 scs-3.2.3 shimmy-0.2.1 stable-baselines3-2.0.0

# %%
# !pip install box2d-py box2d Box2D
# Out:
# Requirement already satisfied: box2d-py in /Users/lucasabbade/opt/anaconda3/lib/python3.10/site-packages (2.3.5)
# Collecting box2d
#   Downloading Box2D-2.3.2.tar.gz (427 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 427.9/427.9 kB 4.2 MB/s eta 0:00:00 MB/s eta 0:00:01
#   Preparing metadata (setup.py) ... done
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py) ... done
#   Created wheel for box2d: filename=Box2D-2.3.2-cp310-cp310-macosx_10_9_x86_64.whl size=418539 sha256=3eb1d5c526f859334a93b0f474a447664a2c0004e7c839a6d8b337881bbb2250
#   Stored in directory: /Users/lucasabbade/Library/Caches/pip/wheels/eb/cb/be/e663f3ce9aba6580611c0febaf7cd3cf7603f87047de2a52f9
# Successfully built box2d
# Installing collected packages: box2d
# Successfully installed box2d-2.3.2

# %%
# !git clone https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Cloning into 'FinRL'...
# remote: Enumerating objects: 12818, done.
# remote: Counting objects: 100% (179/179), done.
# remote: Compressing objects: 100% (120/120), done.
# remote: Total 12818 (delta 96), reused 115 (delta 59), pack-reused 12639
# Receiving objects: 100% (12818/12818), 80.67 MiB | 7.74 MiB/s, done.
# Resolving deltas: 100% (8489/8489), done.

# %%
import os
from typing import List
from argparse import ArgumentParser
from finrl import config
from finrl.config_tickers import DOW_30_TICKER
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
    ERL_PARAMS,
    RLlib_PARAMS,
    SAC_PARAMS,
    ALPACA_API_KEY,
    ALPACA_API_SECRET,
    ALPACA_API_BASE_URL,
)

# construct environment
from finrl.meta.env_stock_trading.env_stocktrading_np import StockTradingEnv
from finrl import train, test, trade

# %%
# "./" will be added in front of each directory
def check_and_make_directories(directories: List[str]):
    for directory in directories:
        if not os.path.exists("./" + directory):
            os.makedirs("./" + directory)

# %% [markdown]
# #### train

# %%
env = StockTradingEnv

# demo for elegantrl
kwargs = {}  # in current meta, with respect yahoofinance, kwargs is {}. For other data sources, such as joinquant, kwargs is not empty
train(
    start_date=TRAIN_START_DATE,
    end_date=TRAIN_END_DATE,
    ticker_list=DOW_30_TICKER,
    data_source="yahoofinance",
    time_interval="1D",
    technical_indicator_list=INDICATORS,
    drl_lib="elegantrl",
    env=env,
    model_name="ppo",
    cwd="./test_ppo",
    erl_params=ERL_PARAMS,
    break_step=1e5,
    kwargs=kwargs,
)

# %% [markdown]
# #### test

# %%
kwargs = {}  # in current meta, with respect yahoofinance, kwargs is {}. For other data sources, such as joinquant, kwargs is not empty

account_value_erl = test(
    start_date=TEST_START_DATE,
    end_date=TEST_END_DATE,
    ticker_list=DOW_30_TICKER,
    data_source="yahoofinance",
    time_interval="1D",
    technical_indicator_list=INDICATORS,
    drl_lib="elegantrl",
    env=env,
    model_name="ppo",
    cwd="./test_ppo",
    net_dimension=512,
    kwargs=kwargs,
)

# %% [markdown]
# #### trade

# %%
env = StockTradingEnv
kwargs = {}
trade(
    start_date=TRADE_START_DATE,
    end_date=TRADE_END_DATE,
    ticker_list=DOW_30_TICKER,
    data_source="yahoofinance",
    time_interval="1D",
    technical_indicator_list=INDICATORS,
    drl_lib="elegantrl",
    env=env,
    model_name="ppo",
    API_KEY=ALPACA_API_KEY,
    API_SECRET=ALPACA_API_SECRET,
    API_BASE_URL=ALPACA_API_BASE_URL,
    trade_mode='backtesting',
    if_vix=True,
    kwargs=kwargs,
)
